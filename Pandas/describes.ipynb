# %%
from main import main

main()

# %%
from PDconfig import df_ML as MeLi, df_LV as LaVoz, df_ZP as ZonaP
from archivosDF import *

df_ML = abrirDF(MeLi)
df_LV = abrirDF(LaVoz)
df_ZP = abrirDF(ZonaP)

df_LV.drop_duplicates(subset='id', keep='last', inplace=True, ignore_index=False)
df_ML.drop_duplicates(subset='id', keep='last', inplace=True, ignore_index=False)
df_ZP.drop_duplicates(subset='id', keep='last', inplace=True, ignore_index=False)

df_LV = df_LV.dropna(how="all", subset=['terrenoTotal', 'terrenoEdificado', 'cantDormitorios', 'cantBanos', 'cantCochera'])
df_ML = df_ML.dropna(how="all", subset=['terrenoTotal', 'terrenoEdificado', 'cantDormitorios', 'cantBanos', 'cantCochera'])
df_ZP = df_ZP.dropna(how="all", subset=['terrenoTotal', 'terrenoEdificado', 'cantDormitorios', 'cantBanos', 'cantCochera'])
# Out:
#              id tipoPropiedad  precioUSD fechaUltimaActualizacion  \
# 0      49445350      TERRENOS      50000               24-07-2022
# 1      51679227  DEPARTAMENTO      39500               16-05-2023
# 2      51413702  DEPARTAMENTO      78000               31-03-2023
# 3      50310364  DEPARTAMENTO     185000               13-09-2022
# 4      51756158          CASA     320000               30-05-2023
# ...         ...           ...        ...                      ...
# 16880  45466895          CASA     185000               25-07-2022
# 16881  45407179          CASA     145000               25-07-2022
# 16882  45336219          CASA     190000               25-07-2022
# 16883  45341640          CASA      75000               25-07-2022
# 16884  45341844  DEPARTAMENTO     120000               25-07-2022
#
#        terrenoTotal  terrenoEdificado  cantDormitorios  cantBanos  \
# 0            2475.0               NaN              NaN        NaN
# ...
